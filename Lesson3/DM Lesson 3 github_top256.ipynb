# %%
from bs4 import BeautifulSoup
import requests

URL_PAGE = "https://gist.github.com/paulmillr/2657075"


def get_soup_from_url(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    return soup


def get_user_list(url):
    res = []
    soup = get_soup_from_url(url)
    table = soup.find('tbody')
    t_row = table.find_all('tr')
    for row in t_row:
        rank = row.find('th').text
        id = row.find('a').text
        link = row.find('a').attrs['href']
        name = row.find('td').text
        # print("rank: %s" % rank)
        # print("id: " + str(id))
        # print("link: " + str(link))
        # print("name: " + str(name))
        # print([rank, id, name])
        res.append([rank, id, name])
    return res

def get_request(url, headers):
    res = requests.get(url, headers=headers)
    return res.json()

def mean(lst):
    if len(lst) == 0:
        return 0
    return sum(lst) / len(lst)

def get_repos_star(user_list):
    for user in user_list:
        url_repo = "https://api.github.com/users/" + user[1] + "/repos"
        headers = {
            'User-Agent': 'Mozilla/5.0',
            'Authorization': 'token f37830758283ea6a2f2d62d608e7cafedb56dc6b',
            'Content-Type': 'application/json',
            'method': 'GET',
            'Accept': 'application/json'
        }

        repos = get_request(url_repo, headers)
        star_list = []
        for repo in repos:
            star_list.append(repo['stargazers_count'])
        star_mean = mean(star_list)
        user.append(star_mean)
        # print(user)
    return user_list

def result_handle(repos_star_list):
    results = sorted(repos_star_list, key=lambda k: k[3], reverse=True)
    for i, r in enumerate(results):
        print("%s %s %s %s %.2f" % (i, r[0], r[1], r[2], r[3]))

if __name__ == "__main__":
    user_list = get_user_list(URL_PAGE)
    # print(user_list)
    repos_star_list = get_repos_star(user_list)

# %%
result_handle(repos_star_list)
# Out:
# 0 #19 kamranahmedse kamranahmedse (Kamran Ahmed) 4608.40
# 1 #226 bailicangdu bailicangdu (cangdu) 3337.74
# 2 #143 vinta vinta (Vinta) 3292.54
# 3 #118 mrdoob mrdoob (Mr.doob) 2269.10
# 4 #45 sebastianbergmann sebastianbergmann (Sebastian Bergmann) 2176.83
# 5 #196 ruanyf ruanyf (Ruan YiFeng) 1935.77
# 6 #154 nolimits4web nolimits4web (Vladimir Kharlampidi) 1903.08
# 7 #231 junyanz junyanz (Jun-Yan Zhu) 1851.93
# 8 #142 avelino avelino (Avelino) 1669.00
# 9 #195 IanLunn IanLunn (Ian Lunn) 1506.33
# 10 #182 jaywcjlove jaywcjlove (小弟调调™) 1455.23
# 11 #110 JakeWharton JakeWharton (Jake Wharton) 1438.13
# 12 #218 josephmisiti josephmisiti (Joseph Misiti) 1424.00
# 13 #134 zenorocha zenorocha (Zeno Rocha) 1373.43
# 14 #209 gorhill gorhill (Raymond Hill) 1243.62
# 15 #107 photonstorm photonstorm (Richard Davey) 1042.47
# 16 #197 binux binux (Roy Binux) 896.36
# 17 #120 fzaninotto fzaninotto (Francois Zaninotto) 788.67
# 18 #66 mdo mdo (Mark Otto) 725.48
# 19 #222 connors connors (Connor Sears) 687.93
# 20 #157 LeaVerou LeaVerou (Lea Verou) 570.23
# 21 #229 amitshekhariitbhu amitshekhariitbhu (AMIT SHEKHAR) 557.70
# 22 #247 Unknwon Unknwon (无闻) 552.20
# 23 #29 ai ai (Andrey Sitnik) 519.27
# 24 #149 toddmotto toddmotto (Todd Motto) 492.33
# 25 #115 mxcl mxcl (Max Howell) 489.97
# 26 #28 steipete steipete (Peter Steinberger) 487.27
# 27 #201 anishathalye anishathalye (Anish Athalye) 475.50
# 28 #112 krzysztofzablocki krzysztofzablocki (Krzysztof Zabłocki) 470.97
# 29 #92 tj tj (TJ Holowaychuk) 463.57
# 30 #191 dennybritz dennybritz (Denny Britz) 452.13
# 31 #190 winterbe winterbe (Benjamin Winterberg) 451.37
# 32 #169 ded ded (Dustin Diaz) 449.38
# 33 #168 Draveness Draveness (Draveness) 424.67
# 34 #213 daylerees daylerees (Dayle Rees) 409.97
# 35 #50 paulmillr paulmillr (Paul Miller) 405.67
# 36 #22 kennethreitz kennethreitz (Kenneth Reitz) 394.30
# 37 #30 mikepenz mikepenz (Mike Penz) 376.97
# 38 #238 matyhtf matyhtf (Tianfeng) 371.36
# 39 #63 chjj chjj (Christopher Jeffrey (JJ)) 359.17
# 40 #249 Shougo Shougo (Shougo) 349.60
# 41 #241 rtomayko rtomayko (Ryan Tomayko) 341.52
# 42 #54 holman holman (Zach Holman) 315.53
# 43 #211 mrmrs mrmrs (Adam Morse) 310.43
# 44 #167 vczh vczh (Zihan Chen) 300.75
# 45 #113 eduardolundgren eduardolundgren (Eduardo Lundgren) 299.27
# 46 #243 be5invis be5invis (Belleve Invis) 296.73
# 47 #61 mgechev mgechev (Minko Gechev) 292.13
# 48 #178 drakeet drakeet (drakeet) 264.40
# 49 #253 JohnSundell JohnSundell (John Sundell) 257.70
# 50 #102 carpedm20 carpedm20 (Taehoon Kim) 247.23
# 51 #62 kylef kylef (Kyle Fuller) 246.53
# 52 #152 ankane ankane (Andrew Kane) 243.47
# 53 #221 overtrue overtrue (安正超) 237.90
# 54 #230 rakyll rakyll (JBD) 227.40
# 55 #96 DataTables DataTables (Allan Jardine) 224.93
# 56 #57 buckyroberts buckyroberts (Bucky Roberts) 212.90
# 57 #185 evilsocket evilsocket (Simone Margaritelli) 209.97
# 58 #172 jendewalt jendewalt (Jen Dewalt) 209.67
# 59 #165 yeasy yeasy (Baohua Yang) 203.70
# 60 #21 bkeepers bkeepers (Brandon Keepers) 187.37
# 61 #255 samuelclay samuelclay (Samuel Clay) 187.30
# 62 #256 unicodeveloper unicodeveloper (Prosper Otemuyiwa) 177.37
# 63 #38 mitchellh mitchellh (Mitchell Hashimoto) 176.20
# 64 #212 siddontang siddontang (siddontang) 175.63
# 65 #78 soumith soumith (Soumith Chintala) 170.23
# 66 #83 alexjlockwood alexjlockwood (Alex Lockwood) 166.90
# 67 #227 nikic nikic (Nikita Popov) 161.17
# 68 #100 tmcw tmcw (Tom MacWright) 148.10
# 69 #65 mcollina mcollina (Matteo Collina) 147.43
# 70 #5 HugoGiraudel HugoGiraudel (Hugo Giraudel) 141.87
# 71 #41 phodal phodal (Phodal Huang) 141.53
# 72 #233 nicolasgramlich nicolasgramlich (Nicolas Gramlich) 139.17
# 73 #43 geerlingguy geerlingguy (Jeff Geerling) 135.90
# 74 #17 GrahamCampbell GrahamCampbell (Graham Campbell) 131.67
# 75 #220 ebidel ebidel (Eric Bidelman) 128.33
# 76 #69 kentcdodds kentcdodds (Kent C. Dodds) 126.27
# 77 #199 leah leah (Leah Culver) 122.00
# 78 #128 marijnh marijnh (Marijn Haverbeke) 121.93
# 79 #79 feross feross (Feross Aboukhadijeh) 119.13
# 80 #94 jverkoey jverkoey (featherless) 118.77
# 81 #205 KittenYang KittenYang (Qitao Yang) 110.60
# 82 #216 philsturgeon philsturgeon (Phil Sturgeon) 106.30
# 83 #237 ericelliott ericelliott (Eric Elliott) 101.87
# 84 #68 muan muan (Mu-An ✌️ Chiou) 99.10
# 85 #239 StephenGrider StephenGrider (Stephen Grider) 98.43
# 86 #156 biezhi biezhi (王爵nice) 97.63
# 87 #121 pissang pissang (Yi Shen) 93.47
# 88 #161 soffes soffes (Sam Soffes) 90.53
# 89 #155 davidfowl davidfowl (David Fowler) 86.63
# 90 #32 hadley hadley (Hadley Wickham) 84.63
# 91 #76 technoweenie technoweenie (risk danger olson) 81.37
# 92 #111 yyx990803 yyx990803 (Evan You) 80.83
# 93 #104 notwaldorf notwaldorf (Monica Dinculescu) 80.70
# 94 #53 zcbenz zcbenz (Cheng Zhao) 77.93
# 95 #82 willdurand willdurand (William Durand) 75.60
# 96 #223 eliben eliben (Eli Bendersky) 74.63
# 97 #148 onevcat onevcat (Wei Wang) 73.37
# 98 #93 jgm jgm (John MacFarlane) 71.80
# 99 #208 passy passy (Pascal Hartig) 71.67
# 100 #188 CamDavidsonPilon CamDavidsonPilon (Cameron Davidson-Pilon) 71.47
# 101 #86 adamwathan adamwathan (Adam Wathan) 70.10
# 102 #133 BurntSushi BurntSushi (Andrew Gallant) 69.33
# 103 #20 joshaber joshaber (Josh Abernathy) 67.87
# 104 #124 paulirish paulirish (Paul Irish) 67.30
# 105 #228 codahale codahale (Coda Hale) 66.33
# 106 #75 dlew dlew (Daniel Lew) 65.27
# 107 #97 SamyPesse SamyPesse (Samy Pessé) 63.97
# 108 #34 Rich-Harris Rich-Harris (Rich Harris) 63.80
# 109 #89 rauchg rauchg (Guillermo Rauch) 63.53
# 110 #60 mhevery mhevery (Miško Hevery) 63.13
# 111 #44 dcramer dcramer (David Cramer) 62.60
# 112 #183 gitster gitster (Junio C Hamano) 62.30
# 113 #116 domenic domenic (Domenic Denicola) 61.27
# 114 #214 weavejester weavejester (James Reeves) 59.70
# 115 #139 xudafeng xudafeng (xdf) 58.33
# 116 #166 mafintosh mafintosh (Mathias Buus) 57.73
# 117 #194 killme2008 killme2008 (dennis zhuang) 57.00
# 118 #131 josevalim josevalim (José Valim) 56.00
# 119 #204 staltz staltz (André Staltz) 55.53
# 120 #219 atian25 atian25 (TZ | 天猪) 51.93
# 121 #236 evanphx evanphx (Evan Phoenix) 50.00
# 122 #91 KrauseFx KrauseFx (Felix Krause) 49.77
# 123 #173 jessfraz jessfraz (Jess Frazelle) 49.60
# 124 #25 atmos atmos (Corey Donohoe) 48.10
# 125 #174 indutny indutny (Fedor Indutny) 48.03
# 126 #77 gaearon gaearon (Dan Abramov) 47.20
# 127 #14 yegor256 yegor256 (Yegor Bugayenko) 47.10
# 128 #234 shiffman shiffman (Daniel Shiffman) 43.33
# 129 #232 simurai simurai (simurai) 41.38
# 130 #74 Caged Caged (Justin Palmer) 40.97
# 131 #27 agentzh agentzh (Yichun Zhang) 40.90
# 132 #242 tomchristie tomchristie (Tom Christie) 38.53
# 133 #217 oldratlee oldratlee (李鼎(哲良)) 37.47
# 134 #108 mattn mattn (mattn) 36.60
# 135 #146 ashfurrow ashfurrow (Ash Furrow) 35.97
# 136 #246 remy remy (Remy Sharp) 35.67
# 137 #240 AdamBien AdamBien (Adam Bien) 35.60
# 138 #138 bevacqua bevacqua (Nicolás Bevacqua) 33.40
# 139 #153 keijiro keijiro (Keijiro Takahashi) 32.80
# 140 #137 radar radar (Ryan Bigg) 32.47
# 141 #163 Jinjiang Jinjiang (勾三股四) 31.83
# 142 #42 jwiegley jwiegley (John Wiegley) 31.30
# 143 #244 amueller amueller (Andreas Mueller) 30.60
# 144 #71 mitsuhiko mitsuhiko (Armin Ronacher) 30.13
# 145 #16 rstacruz rstacruz (Rico Sta. Cruz) 28.47
# 146 #206 leebyron leebyron (Lee Byron) 28.47
# 147 #56 yihui yihui (Yihui Xie) 27.67
# 148 #73 hzoo hzoo (Henry Zhu) 26.13
# 149 #103 benjamn benjamn (Ben Newman) 26.07
# 150 #126 madskristensen madskristensen (Mads Kristensen) 24.93
# 151 #184 djspiewak djspiewak (Daniel Spiewak) 23.77
# 152 #7 bebraw bebraw (Juho Vepsäläinen) 23.47
# 153 #87 Haacked Haacked (Phil Haack) 23.30
# 154 #251 benoitc benoitc (Benoit Chesneau) 22.70
# 155 #202 pkrumins pkrumins (Peter Krumins) 22.27
# 156 #13 jxnblk jxnblk (Brent Jackson) 21.93
# 157 #51 tmm1 tmm1 (Aman Gupta) 21.30
# 158 #48 jdalton jdalton (John-David Dalton) 20.64
# 159 #252 ask ask (Ask Solem) 20.03
# 160 #181 sdiehl sdiehl (Stephen Diehl) 19.13
# 161 #180 ahmetb ahmetb (Ahmet Alp Balkan) 18.77
# 162 #84 matsko matsko (Matias Niemelä) 17.66
# 163 #144 developit developit (Jason Miller) 17.37
# 164 #159 odersky odersky 17.33
# 165 #203 isaacs isaacs (isaacs) 16.73
# 166 #122 jamesmontemagno jamesmontemagno (James Montemagno) 16.70
# 167 #31 nvie nvie (Vincent Driessen) 16.40
# 168 #12 benbalter benbalter (Ben Balter) 15.60
# 169 #135 contra contra (contra) 14.87
# 170 #106 rnystrom rnystrom (Ryan Nystrom) 14.83
# 171 #6 ornicar ornicar (Thibault Duplessis) 14.80
# 172 #70 jskeet jskeet (Jon Skeet) 14.07
# 173 #147 f f (Fatih Kadir Akın) 13.93
# 174 #90 ianstormtaylor ianstormtaylor (Ian Storm Taylor) 13.87
# 175 #46 brunocvcunha brunocvcunha (Bruno Volpato) 13.80
# 176 #4 egoist egoist (EGOIST) 13.60
# 177 #1 fabpot fabpot (Fabien Potencier) 13.37
# 178 #23 kytrinyx kytrinyx (Katrina Owen) 13.23
# 179 #132 jennybc jennybc (Jennifer (Jenny) Bryan) 11.93
# 180 #193 maryrosecook maryrosecook (Mary Rose Cook) 11.73
# 181 #109 dougwilson dougwilson (Douglas Wilson) 10.30
# 182 #254 Raynos Raynos (Jake Verbaten) 10.27
# 183 #58 kbrsh kbrsh (Kabir Shah) 10.23
# 184 #35 drnic drnic (Dr Nic Williams) 10.00
# 185 #3 taylorotwell taylorotwell (Taylor Otwell) 9.83
# 186 #145 ashleygwilliams ashleygwilliams (ashley williams) 9.73
# 187 #224 Seldaek Seldaek (Jordi Boggiano) 8.83
# 188 #158 davidtmiller davidtmiller (David Miller) 8.80
# 189 #64 ayende ayende (Ayende Rahien) 8.77
# 190 #10 jonathanong jonathanong (jongleberry) 8.37
# 191 #119 josegonzalez josegonzalez (Jose Diaz-Gonzalez) 8.07
# 192 #245 dead-horse dead-horse (Yiyu He) 7.63
# 193 #177 laanwj laanwj (Wladimir J. van der Laan) 7.17
# 194 #215 zce zce (汪磊) 7.03
# 195 #151 EisenbergEffect EisenbergEffect (Rob Eisenberg) 7.00
# 196 #235 purcell purcell (Steve Purcell) 7.00
# 197 #88 curran curran (Curran Kelleher) 6.70
# 198 #187 shama shama (Kyle Robinson Young) 6.67
# 199 #125 samdark samdark (Alexander Makarov) 6.60
# 200 #80 michalbe michalbe (Michał Budzyński) 6.27
# 201 #225 joyeecheung joyeecheung (Joyee Cheung) 6.03
# 202 #55 kevinsawicki kevinsawicki (Kevin Sawicki) 5.97
# 203 #105 miyagawa miyagawa (Tatsuhiko Miyagawa) 5.87
# 204 #52 c9s c9s (Yo-An Lin) 5.67
# 205 #210 phuslu phuslu (phuslu) 5.63
# 206 #26 weierophinney weierophinney (Matthew Weier O'Phinney) 5.50
# 207 #192 arun-gupta arun-gupta (Arun Gupta) 5.37
# 208 #9 alexcrichton alexcrichton (Alex Crichton) 5.17
# 209 #140 j2kun j2kun (Jeremy Kun) 4.97
# 210 #117 alex alex (Alex Gaynor) 4.93
# 211 #141 dominictarr dominictarr (Dominic Tarr) 4.87
# 212 #186 mariotaku mariotaku (Mariotaku) 4.73
# 213 #98 mjhea0 mjhea0 (Michael Herman) 4.53
# 214 #136 jaredhanson jaredhanson (Jared Hanson) 4.43
# 215 #160 vhf vhf (victor felder) 4.13
# 216 #15 orta orta (Orta) 4.03
# 217 #164 happypeter happypeter (Peter Wang) 3.73
# 218 #67 yoshuawuyts yoshuawuyts (Yoshua Wuyts) 3.70
# 219 #129 alanhamlett alanhamlett (Alan Hamlett) 3.70
# 220 #101 brentvatne brentvatne (Brent Vatne) 3.63
# 221 #176 i5ting i5ting (他们叫我狼叔) 3.57
# 222 #162 mxstbr mxstbr (Max Stoiber) 3.53
# 223 #37 Ocramius Ocramius (Marco Pivetta) 3.40
# 224 #95 chenglou chenglou (Cheng Lou) 3.37
# 225 #170 vladikoff vladikoff (Vlad Filippov) 2.90
# 226 #33 appleboy appleboy (Bo-Yi Wu) 2.77
# 227 #198 nfultz nfultz (Neal Fultz) 2.77
# 228 #40 IgorMinar IgorMinar (Igor Minar) 2.67
# 229 #2 andrew andrew (Andrew Nesbitt) 2.43
# 230 #11 mikermcneil mikermcneil (Mike McNeil) 2.33
# 231 #72 steveklabnik steveklabnik (Steve Klabnik) 2.30
# 232 #81 brianleroux brianleroux (Brian LeRoux) 2.17
# 233 #171 bnoordhuis bnoordhuis (Ben Noordhuis) 1.90
# 234 #250 arunoda arunoda (Arunoda Susiripala) 1.90
# 235 #200 suissa suissa (Jean Carlo Nascimento) 1.87
# 236 #18 afc163 afc163 (偏右) 1.70
# 237 #207 fengmk2 fengmk2 (fengmk2) 1.50
# 238 #59 dmalan dmalan (David J. Malan) 1.43
# 239 #8 nelsonic nelsonic (Nelson) 1.40
# 240 #127 sokra sokra (Tobias Koppers) 1.40
# 241 #24 STRML STRML (Samuel Reed) 1.30
# 242 #114 vjeux vjeux (Christopher Chedeau) 1.20
# 243 #85 stefanpenner stefanpenner (Stefan Penner) 1.13
# 244 #130 wesm wesm (Wes McKinney) 0.97
# 245 #49 sevilayha sevilayha (Chris Sevilleja) 0.93
# 246 #36 rafaelfranca rafaelfranca (Rafael França) 0.90
# 247 #189 dsyer dsyer (Dave Syer) 0.90
# 248 #39 stof stof (Christophe Coevoet) 0.87
# 249 #47 ljharb ljharb (Jordan Harband) 0.80
# 250 #248 jiyinyiyong jiyinyiyong (Jon Chen) 0.63
# 251 #99 0x00A 0x00A (paolo fragomeni) 0.00
# 252 #123 paulcbetts paulcbetts (Paul Betts) 0.00
# 253 #150 gdi2290 gdi2290 (PatrickJS [tipe.io]) 0.00
# 254 #175 olivergierke olivergierke (Oliver Gierke) 0.00
# 255 #179 thejameskyle thejameskyle (James Kyle) 0.00
